# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uRwIpRglet2KAEkVGKPK")
project = rf.workspace().project("weapon-detection-tkam6")
dataset = project.version(5).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# ...
# ...
# Extracting Dataset Version Zip to Weapon-Detection-5 in yolov5pytorch::   0%|          | 0/3354 [00:00<?, ?it/s]
# Extracting Dataset Version Zip to Weapon-Detection-5 in yolov5pytorch::  26%|██▌       | 863/3354 [00:00<00:00, 8627.11it/s]
# Extracting Dataset Version Zip to Weapon-Detection-5 in yolov5pytorch::  53%|█████▎    | 1765/3354 [00:00<00:00, 8855.81it/s]
# Extracting Dataset Version Zip to Weapon-Detection-5 in yolov5pytorch::  94%|█████████▍| 3160/3354 [00:00<00:00, 11180.16it/s]
# Extracting Dataset Version Zip to Weapon-Detection-5 in yolov5pytorch:: 100%|██████████| 3354/3354 [00:00<00:00, 10589.36it/s]
